# %%
import pandas as pd

# %%
import numpy as np
from matplotlib.pyplot import scatter

xx = np.array([0, 50])
yy = np.array([0, 10])
means = [xx.mean(), yy.mean()]  
stds = [xx.std() / 3, yy.std() / 3]
corr = -0.9        # correlation
covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 

m2 = np.random.multivariate_normal(means, covs, 50).T

scatter(m2[0], m2[1])

# %%
m = m.T
m2 = m2.T

# %%
m.shape
# Out:
# (50, 2)

# %%
data_arr = np.concatenate([m, m2], axis=1)

# %%
data_arr.shape
# Out:
# (50, 4)

# %%
df = pd.DataFrame(data=data_arr, columns=["A", "B", "C", "D"])

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
pd.plotting.scatter_matrix(df, alpha=.5);

# %%
df.to_csv("data.csv", index=False)

# %%
df.to_json("data.json", orient="records")
